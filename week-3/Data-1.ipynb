# %%
import pandas as pd
data = pd.read_csv("B:\prepinsta\week-3\Data-cleaning-for-beginners-using-pandas.csv")
print(data)
print(type(data))
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.isnull()
# Out:
#     Index    Age  Salary  Rating  Location  Established  Easy Apply
# 0   False  False   False   False     False        False       False
# 1   False  False   False   False     False        False       False
# 2   False   True   False   False     False        False       False
# 3   False  False   False   False     False        False       False
# 4   False  False   False   False     False        False       False
# 5   False  False   False   False     False        False       False
# 6   False  False   False   False     False        False       False
# 7   False  False   False   False     False        False       False
# 8   False  False   False   False     False        False       False
# 9   False  False   False   False     False        False       False
# 10  False  False   False   False     False        False       False
# 11  False  False   False   False     False        False       False
# 12  False   True   False   False     False        False       False
# ...

# %%
daat_frame =data.copy()

# %%
daat_frame.isnull()
daat_frame.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
daat_frame.iloc[0:2,0:3]
# Out:
#    Index   Age     Salary
# 0      0  44.0  $44k-$99k
# 1      1  66.0  $55k-$66k

# %%
daat_frame.isnull()
# Out:
#     Index    Age  Salary  Rating  Location  Established  Easy Apply
# 0   False  False   False   False     False        False       False
# 1   False  False   False   False     False        False       False
# 2   False   True   False   False     False        False       False
# 3   False  False   False   False     False        False       False
# 4   False  False   False   False     False        False       False
# 5   False  False   False   False     False        False       False
# 6   False  False   False   False     False        False       False
# 7   False  False   False   False     False        False       False
# 8   False  False   False   False     False        False       False
# 9   False  False   False   False     False        False       False
# 10  False  False   False   False     False        False       False
# 11  False  False   False   False     False        False       False
# 12  False   True   False   False     False        False       False
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Index', 'Age', 'Salary', 'Rating', 'Location', 'Established',
#        'Easy Apply'],
#       dtype='object')

# %%
sample = data.columns.str.lower().str.replace(" ","_")
text = '$40k-$100k'
text.replace('$',"")
# Out:
# '40k-100k'

# %%
sample
# Out:
# Index(['index', 'age', 'salary', 'rating', 'location', 'established',
#        'easy_apply'],
#       dtype='object')

# %%
avg_age = data['Age'].mean()
avg_age
# Out:
# 39.04545454545455

# %%
data['Age'] = data.Age.fillna(avg_age)
data['Age'] = data.Age.round(decimals=1)

# %%
data.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2  39.0  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data['Age']
# Out:
# 0     44.0
# 1     66.0
# 2     39.0
# 3     64.0
# 4     25.0
# 5     44.0
# 6     21.0
# 7     44.0
# 8     35.0
# 9     22.0
# 10    55.0
# 11    44.0
# 12    39.0
# 13    25.0
# 14    66.0
# 15    44.0
# 16    19.0
# 17    39.0
# 18    35.0
# 19    32.0
# 20    39.0
# 21    35.0
# 22    19.0
# 23    39.0
# 24    13.0
# 25    55.0
# 26    39.0
# 27    52.0
# 28    39.0
# Name: Age, dtype: float64

# %%
data['Location'].value_counts()
# Out:
# Location
# New York,Ny      12
# India,In          9
# Australia Aus     7
# India In          1
# Name: count, dtype: int64

# %%
data['Location'] = data['Location'].replace({'New York,Ny':'New York', 'India,In':'India','India In':'India', 'Australia Aus':'Australia'})


data['Location'] = data['Location'].str.replace(r'\sIn$', '')
l = ['India','In']
l[1]

data['Location'].str.split(",",expand=True)[0]
# Out:
# 0         India
# 1      New York
# 2      New York
# 3         India
# 4     Australia
# 5         India
# 6      New York
# 7     Australia
# 8      New York
# 9         India
# 10        India
# 11        India
# 12        India
# 13    Australia
# 14    Australia
# 15    Australia
# 16        India
# 17     New York
# 18     New York
# 19     New York
# 20     New York
# 21     New York
# 22     New York
# 23     New York
# 24     New York
# 25    Australia
# 26        India
# 27        India
# 28    Australia
# Name: 0, dtype: object

# %%
data['Age'].fillna(45, inplace=True)
print(data)
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      India         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   New York         2002       TRUE
# 2       2  39.0   $77k-$89k    -1.0   New York           -1         -1
# 3       3  64.0   $44k-$99k     4.4      India         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      India         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   New York           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia           -1         -1
# 8       8  35.0   $44k-$99k     5.4   New York           -1         -1
# 9       9  22.0   $44k-$99k     7.7      India           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4      India         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      India         2009         -1
# ...

# %%
data.loc[(data['Rating'] == -1.0) | data['Rating'].isna(), 'Rating'] = data['Rating'].fillna(2)

print(data)
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      India         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   New York         2002       TRUE
# 2       2  39.0   $77k-$89k    -1.0   New York           -1         -1
# 3       3  64.0   $44k-$99k     4.4      India         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      India         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   New York           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia           -1         -1
# 8       8  35.0   $44k-$99k     5.4   New York           -1         -1
# 9       9  22.0   $44k-$99k     7.7      India           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4      India         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      India         2009         -1
# ...

# %%
data.loc[(data['Rating'] == -1.0) | data['Rating'].isna(), 'Rating'] = 2


data.loc[data['Established'] == -1, 'Established'] = 2002



print(data)
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      India         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   New York         2002       TRUE
# 2       2  39.0   $77k-$89k     2.0   New York         2002         -1
# 3       3  64.0   $44k-$99k     4.4      India         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      India         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   New York         2002         -1
# 7       7  44.0   $44k-$99k     2.0  Australia         2002         -1
# 8       8  35.0   $44k-$99k     5.4   New York         2002         -1
# 9       9  22.0   $44k-$99k     7.7      India         2002       TRUE
# 10     10  55.0   $10k-$49k     5.4      India         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      India         2009         -1
# ...

# %%
salary = '$40k-$100k'
salary.replace('$',"")
print(data)
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      India         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   New York         2002       TRUE
# 2       2  39.0   $77k-$89k     2.0   New York         2002         -1
# 3       3  64.0   $44k-$99k     4.4      India         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      India         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   New York         2002         -1
# 7       7  44.0   $44k-$99k     2.0  Australia         2002         -1
# 8       8  35.0   $44k-$99k     5.4   New York         2002         -1
# 9       9  22.0   $44k-$99k     7.7      India         2002       TRUE
# 10     10  55.0   $10k-$49k     5.4      India         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      India         2009         -1
# ...

# %%
print(data['Easy Apply'].unique())
data['Easy Apply'].fillna(False, inplace=False)
data.loc[data['Easy Apply'] == -1, 'Easy Apply'] = False
# Out:
# ['TRUE' '-1']

# %%
data.loc[data['Easy Apply'] == -1, 'Easy Apply'] = "FALSE"

# %%
data.isnull()
# Out:
#     Index    Age  Salary  Rating  Location  Established  Easy Apply
# 0   False  False   False   False     False        False       False
# 1   False  False   False   False     False        False       False
# 2   False  False   False   False     False        False       False
# 3   False  False   False   False     False        False       False
# 4   False  False   False   False     False        False       False
# 5   False  False   False   False     False        False       False
# 6   False  False   False   False     False        False       False
# 7   False  False   False   False     False        False       False
# 8   False  False   False   False     False        False       False
# 9   False  False   False   False     False        False       False
# 10  False  False   False   False     False        False       False
# 11  False  False   False   False     False        False       False
# 12  False  False   False   False     False        False       False
# ...

# %%
print(data)
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      India         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   New York         2002       TRUE
# 2       2  39.0   $77k-$89k     2.0   New York         2002         -1
# 3       3  64.0   $44k-$99k     4.4      India         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      India         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   New York         2002         -1
# 7       7  44.0   $44k-$99k     2.0  Australia         2002         -1
# 8       8  35.0   $44k-$99k     5.4   New York         2002         -1
# 9       9  22.0   $44k-$99k     7.7      India         2002       TRUE
# 10     10  55.0   $10k-$49k     5.4      India         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      India         2009         -1
# ...

# %%
#ye value change nhi ho raha h yrrrrrrrrrrrrrrrrrrrrrrrrrrrr
